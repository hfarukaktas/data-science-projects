# %%
#imports

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Gold_vs_Economic_Factors_2015_2026.csv")

# %% [markdown]
# ## Data Inspection

# %%
df.head()
# Out:
#          Date  Gold_Price_XAU_USD  US_Dollar_Index_DXY  Crude_Oil_Price  \
# 0  2015-01-01             1205.47                95.17            47.85
# 1  2015-01-02             1204.58                95.61            48.71
# 2  2015-01-03             1211.56                95.62            53.73
# 3  2015-01-04             1227.29                95.93            55.39
# 4  2015-01-05             1225.45                96.75            53.76
#
#    Inflation_Rate_Pct
# 0                7.92
# 1                6.17
# 2                4.80
# 3                6.95
# 4                5.99

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4137 entries, 0 to 4136
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 4137 non-null   object
#  1   Gold_Price_XAU_USD   4137 non-null   float64
#  2   US_Dollar_Index_DXY  4137 non-null   float64
#  3   Crude_Oil_Price      4137 non-null   float64
#  4   Inflation_Rate_Pct   4137 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 161.7+ KB

# %%
df.describe()
# Out:
#        Gold_Price_XAU_USD  US_Dollar_Index_DXY  Crude_Oil_Price  \
# count         4137.000000          4137.000000      4137.000000
# mean          2825.359197            55.311615       274.739901
# std            927.408308            17.148820        88.498329
# min           1106.380000            27.050000        47.850000
# 25%           2034.880000            39.280000       227.140000
# 50%           3047.790000            53.110000       282.700000
# 75%           3625.970000            72.520000       320.750000
# max           4176.600000            97.090000       463.810000
#
#        Inflation_Rate_Pct
# count         4137.000000
# mean             5.065886
# std              2.011200
# min              1.500000
# 25%              3.370000
# 50%              5.090000
# 75%              6.760000
# max              8.500000
